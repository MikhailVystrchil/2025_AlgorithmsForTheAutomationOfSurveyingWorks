# %% [markdown]
# # Задачи на цикл ```while```

# %% [markdown]
# ## Задача 5.1
#
# Дано целое число, не меньшее `2`.
#
# Выведите его наименьший натуральный делитель, отличный от `1`.
#
#
# **Входные данные**
#
# Вводится натуральное число `N > 2`.
#
# **Выходные данные**
#
# Вывести ответ на задачу.

# %% [markdown]
# ---
# ---
# ## Задача 5.2
#
# Последовательность Фибоначчи определяется так:
#
# $$ f_1=0, f_2=1, f_3=1, f_4=2, f_5=3, f_6=5, f_7=8    \dots,     f_n=f_{n-1}+f_{n-2} $$
#
# По данному числу $n$ определите $n$-е число Фибоначчи $f_n$.
#
# **Входные данные**
#
# Вводится натуральное число `n`.
#
# **Выходные данные**
#
# Вывести ответ на задачу.

# %% [markdown]
# ---
# ---
# ## Задача 5.3
#
# Вводятся два натуральных числа.
#
# Необходимо вывести их __наибольший общий делитель__.
#
# > Подумайте как можно повысить эффективность алгоритма!
#
# **Входные данные**
#
# На вход подаётся два натуральных числа.
#
# **Выходные данные**
#
# Выведите ответ на задачу.

# %% [markdown]
# ---
# ---
# ## Задача 5.4
#
# Вводятся два натуральных числа.
#
# Необходимо вывести их __наименьшее общие кратное__.
#
# **Входные данные**
#
# На вход подаётся два натуральных числа.
#
# **Выходные данные**
#
# Выведите ответ на задачу.

# %% [markdown]
# ---
# ---
# ## Задача 5.5
#
# Последовательность вводимых чисел состоит из натуральных чисел и __завершается__ числом `0`.
#
# Определите, сколько элементов этой последовательности больше предыдущего элемента.
#
# **Входные данные**
#
# Вводится последовательность из натуральных чисел (гарантируется, что количество чисел в последовательности больше `2`)
#
# **Выходные данные**
#
# Вывести ответ на задачу.
#
# **Sample Input:**
#
# 1
#
# 2
#
# 3
#
# 4
#
# 0
#
# **Sample Output:**
#
# 3

# %% [markdown]
# ---
# ---
# ## Задача 5.6
#
# Последовательность состоит из натуральных чисел и __завершается__ числом `0`.
#
# Определите, какое количество элементов этой последовательности, равны ее наибольшему элементу.
#
# > Решите эту задачу, не пользуясь списками!
#
# **Входные данные**
#
# Вводится последовательность из натуральных чисел (гарантируется, что количество чисел в последовательности больше `2`)
#
# **Выходные данные**
#
# Вывести ответ на задачу.

# %% [markdown]
# ---
# ---
# ## Задача 5.7
#
# Последовательность состоит из натуральных чисел и __завершается__ числом `0`.
#
# Определите значение __второго минимального по величине элемента__ в этой последовательности, то есть элемента, который будет наименьшим, если из последовательности удалить наименьший элемент.
#
# > Последнее число `0` не учитывается.
#
# Гарантируется, что в последовательности есть хотя бы два элемента (кроме завершающего числа `0`).
#
#
# **Входные данные**
#
# На вход подаётся последовательность целых неотрицательных чисел, заканчивающаяся нулём.
# Все числа в последовательности неотрицательные.
#
# **Выходные данные**
#
# Выведите ответ на задачу.

# %% [markdown]
# ---
# ---
# ## Задача 5.8
#
# Вводится натуральное число `n`.
#
# Вывести сумму его цифр.
#
# **Входные данные**
#
# Вводится натуральное число `n = 12345`.
#
# **Выходные данные**
#
# Вывести ответ на задачу (`15`).

# %% [markdown]
# ---
# ---
# ## Задача 5.9
#
# Вводится натуральное число `n`.
#
# Переставьте цифры числа в обратном порядке.
#
# **Входные данные**
#
# Вводится натуральное число `n = 123456`.
#
# **Выходные данные**
# Вывести ответ на задачу (`654321`).
#
# > Постарайтесь оптимизировать решение задачи!

# %% [markdown]
# ---
# ---
# ## Задача 5.10
#
# Вводится натуральное число `n`.
#
# Если число является палиндром, вывести ```Yes```, иначе вывести ```No```.
#
# Назовем число палиндромом, если оно не меняется при перестановке его цифр в обратном порядке.
#
# **Входные данные**
#
# Вводится натуральное число `n = 123454321`.
#
# **Выходные данные**
#
# Вывести ответ на задачу (`"YES"`).

# %% [markdown]
# ---
# ---
