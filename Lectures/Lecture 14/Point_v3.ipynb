# %% [markdown]
# # Опять страдаем с точкой
#
# ## Работа с `__setattr__`

# %%
class Point:

    def __init__(self, x, y, z=0):
        self.x = x
        self.y = y
        self.z = z

    def __setattr__(self, name, value):
        if name in ["x", "y", "z"]:
            value = self._check_xyz_data(value)
        super().__setattr__(name, value)

    @staticmethod
    def _check_xyz_data(value):
        if isinstance(value, float):
            return value
        elif isinstance(value, int):
            return float(value)
        else:
            raise ValueError(f"Должно быть число! Передан тип: {type(value)} - {value}")

# %%
p1 = Point(10, 10)
print(p1)

# p2 = Point("Двадцать", 20, 20)
# print(p2)

p3 = Point(30, 30, 30)
print(p3)
    
# p3.x = "Тридцать"
# print(p3)

p2 = Point(20, 20, 20)
# p2.x = "Двадцать"
# print(p2)

# %%
class Point:

    def __init__(self, x, y, z=0.0):
        self._x = x
        self._y = y
        self._z = z

    def __setattr__(self, name, value):
        if name in ["_x", "_y", "_z"]:
            value = self._check_xyz_data(value)
        super().__setattr__(name, value)

    @property
    def x(self):
        return self._x

    @property
    def y(self):
        return self._y

    @property
    def z(self):
        return self._z

    @x.setter
    def x(self, value):
        self._x = value

    @y.setter
    def y(self, value):
        self._y = value

    @z.setter
    def z(self, value):
        self._z = value

    @staticmethod
    def _check_xyz_data(value):
        if isinstance(value, float):
            return value
        elif isinstance(value, int):
            return float(value)
        else:
            raise ValueError(f"Должно быть число! Передан тип: {type(value)} - {value}")

# %%
p1 = Point(10, 10)
print(p1)

# p2 = Point("Двадцать", 20, 20)
# print(p2)

p3 = Point(30, 30, 30)
print(p3)
    
# p3.x = "Тридцать"
# print(p3)

p2 = Point(20, 20, 20)
# p2.x = "Двадцать"
# print(p2)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Работа с `__str__` и `__repr__`

# %%
class Point:

    def __init__(self, x, y, z=0):
        self.x = self._check_xyz_data(x)
        self.y = self._check_xyz_data(y)
        self.z = self._check_xyz_data(z)

    def __setattr__(self, name, value):
        if name in ["x", "y", "z"]:
            value = self._check_xyz_data(value)
        super().__setattr__(name, value)

    def __str__(self):
        return f"Point (x={self.x}, y={self.y}, z={self.z})"

    # def __repr__(self):
    #     return f"({self.x}, {self.y}, {self.z})"

    @staticmethod
    def _check_xyz_data(value):
        if isinstance(value, float):
            return value
        elif isinstance(value, int):
            return float(value)
        else:
            raise ValueError(f"Должно быть число! Передан тип: {type(value)} - {value}")

# %%
p1 = Point(10, 10)
print(p1)

p2 = Point(20, 20, 20)
print(p2)

p3 = Point(30, 30, 30)
print(p3)

point_list = [p1, p2, p3]
print(point_list)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Работа с `__eq__`

# %%
class Point:

    def __init__(self, x, y, z=0.0):
        self.x = self._check_xyz_data(x)
        self.y = self._check_xyz_data(y)
        self.z = self._check_xyz_data(z)

    def __setattr__(self, name, value):
        if name in ["x", "y", "z"]:
            value = self._check_xyz_data(value)
        super().__setattr__(name, value)

    def __str__(self):
        return f"Point (x={self.x}, y={self.y}, z={self.z})"

    def __repr__(self):
        return f"({self.x}, {self.y}, {self.z})"

    # def __eq__(self, other):
    #     return self.x == other.x and self.y == other.y and self.z == other.z

    @staticmethod
    def _check_xyz_data(value):
        if isinstance(value, float):
            return value
        elif isinstance(value, int):
            return float(value)
        else:
            raise ValueError(f"Должно быть число! Передан тип: {type(value)} - {value}")

# %%
p1 = Point(10, 10)
print(p1)

p2 = Point(20, 20, 20)
print(p2)

p3 = Point(30, 30, 30)
print(p3)

p4 = Point(30.0, 30.0, 30.0)
print(p4)

print("*" * 50)

print(p1 == p2, p1 is p2)
print(p3 == p4, p3 is p4)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Работа с `__hash__`

# %%
import timeit
from sys import getsizeof


class Point:

    def __init__(self, x, y, z=0.0):
        self.x = x
        self.y = y
        self.z = z

    def __setattr__(self, name, value):
        if name in ["x", "y", "z"]:
            value = self._check_xyz_data(value)
        super().__setattr__(name, value)

    def __str__(self):
        return f"Point (x={self.x}, y={self.y}, z={self.z})"

    def __repr__(self):
        return f"({self.x}, {self.y}, {self.z})"

    def __eq__(self, other):
        print(f"проверяем на равенство точки: {self} - {other}")
        return self.x == other.x and self.y == other.y and self.z == other.z

    def __hash__(self):
        # return 1
        return int(self.x + self.y + self.z)
        # return int(self.x * self.y * self.z)

    @staticmethod
    def _check_xyz_data(value):
        if isinstance(value, float):
            return value
        elif isinstance(value, int):
            return float(value)
        else:
            raise ValueError(f"Должно быть число! Передан тип: {type(value)} - {value}")

# %%
p1 = Point(10, 10)
print("p1", p1)

p2 = Point(20, 20, 20)
print("p2", p2)

p3 = Point(30, 30, 30)
print("p3", p3)

p4 = Point(30.0, 30.0, 30.0)
print("p4", p4)

print("*" * 50)

set_ = {p1, p2, p3, p4}
print(set_)

print("*" * 50)

# dict_ = {p1: repr(p1),
#          p2: repr(p2),
#          p3: repr(p3),
#          p4: repr(p4),
#         }
# print(dict_)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Повышение производительности

# %%
class Point:

    __slots__ = ["x", "y", "z"]

    def __init__(self, x, y, z=0.0):
        self.x = x
        self.y = y
        self.z = z

    # def __setattr__(self, name, value):
    #     if name in ["x", "y", "z"]:
    #         value = self._check_xyz_data(value)
    #     super().__setattr__(name, value)

    def __str__(self):
        return f"Point (x={self.x}, y={self.y}, z={self.z})"

    def __repr__(self):
        return f"({self.x}, {self.y}, {self.z})"

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y and self.z == other.z

    def __hash__(self):
        return int(self.x * self.y * self.z)

    @staticmethod
    def _check_xyz_data(value):
        if isinstance(value, float):
            return value
        elif isinstance(value, int):
            return float(value)
        else:
            raise ValueError(f"Должно быть число! Передан тип: {type(value)} - {value}")

# %%
import timeit

code_str = "Point(30.0, 30.0, 30.0)"
time1 = timeit.timeit(code_str, setup="from __main__ import Point", number=1_000_000)
print(time1)

# %%
from sys import getsizeof

point_list = [Point(30, 30, 30) for _ in range(1_000_000)]
print(getsizeof(point_list))

# %%
import sys
from pympler import asizeof
    
point_list = [Point(10, 20, 30) for _ in range(10 ** 6)]
print(f"asizeof: {asizeof.asizeof(point_list)} vs {sys.getsizeof(point_list)}")

# %%
p = Point(10, 20, 30)

print(p.__slots__)
# print(p.__dict__)
p.name = 123
print(p, p.name)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Класс ScanPoint

# %%
class Point:

    __slots__ = ["x", "y", "z"]

    def __init__(self, x, y, z=0.0):
        self.x = x
        self.y = y
        self.z = z

    def __str__(self):
        return f"Point (x={self.x}, y={self.y}, z={self.z})"

    def __repr__(self):
        return f"({self.x}, {self.y}, {self.z})"

    def __eq__(self, other):
        if not isinstance(other, Point):
            return NotImplemented
        return (self.x, self.y, self.z) == (other.x, other.y, other.z)

    def __hash__(self):
        return hash((self.x, self.y, self.z))

# %% [markdown]
# ---

# %%
class Color:
    __slots__ = ["r", "g", "b"]

    def __init__(self, r, g, b):
        self.r = r
        self.g = g
        self.b = b

    @property
    def rgb(self):
        return self.r, self.g, self.b

    def __repr__(self):
        return f"({self.r}, {self.g}, {self.b})"

    def __eq__(self, other):
        if not isinstance(other, Color):
            return NotImplemented
        return self.rgb == other.rgb

    def __hash__(self):
        return hash(self.rgb)

# %%
c = Color(255, 0, 0)
print(c)
print(c.rgb)

# %%
c = Color(255, 0, 0)

rgb = c.rgb

print(type(rgb), rgb)

# %% [markdown]
# ---

# %% [markdown]
# ## Через наследование

# %%
class ScanPoint(Point, Color):
    __slots__ = ["x", "y", "z", "r", "g", "b"]

    def __init__(self, x, y, z, color):
        Point.__init__(self, x, y, z)
        Color.__init__(self, color[0], color[1], color[2])

    def __str__(self):
        return f"ScanPoint (x={self.x}, y={self.y}, x={self.z}, color=({self.r}, {self.g}, {self.b}))"

# %% [markdown]
# `ScanPoint(Point, Color)` не работает, потому что у `Point` и `Color` разные `__slots__`, и интерпретатор не может совместить их внутренние структуры объекта (`instance layout`) в одном наследнике .
#
# У каждого класса со `__slots__` Python жёстко фиксирует, какие поля и в каком порядке лежат в объекте в памяти; когда ты делаешь множественное наследование от двух таких классов, он не понимает, как объединить две разные схемы хранения в одну, и выдаёт `TypeError: multiple bases have instance lay-out conflict`.

# %% [markdown]
# ---

# %% [markdown]
# ## Через композицию

# %%
class ScanPoint:
    __slots__ = ["point", "color"]

    def __init__(self, x, y, z, color):
        self.point = Point(x, y, z)
        self.color = color if isinstance(color, Color) else Color(*color)

    def __str__(self):
        p = self.point
        c = self.color
        return f"ScanPoint (x={p.x}, y={p.y}, z={p.z}, color=({c.r}, {c.g}, {c.b}))"

    def __repr__(self):
        p = self.point
        c = self.color
        return f"ScanPoint({p.x}, {p.y}, {p.z}, ({c.r}, {c.g}, {c.b}))"

# %%
import timeit

code_str = "ScanPoint(30.0, 30.0, 30.0, (255, 0, 0))"
time1 = timeit.timeit(code_str, setup="from __main__ import ScanPoint", number=1_000_000)
print(time1)

# %% [markdown]
# ---

# %%
class Point:
    __slots__ = ["x", "y", "z"]

    def __init__(self, x, y, z=0.0):
        self.x, self.y, self.z = x, y, z


class Color:
    __slots__ = ["r", "g", "b"]

    def __init__(self, r, g, b):
        self.r, self.g, self.b = r, g, b

    @property
    def rgb(self):
        return self.r, self.g, self.b

    def __repr__(self):
        return f"Color(r={self.r}, g={self.g}, b={self.b})"

# %%
class ScanPoint(Point):
    __slots__ = ["color"]

    def __init__(self, x, y, z, color):
        super().__init__(x, y, z)
        self.color = Color(*color)

    def __str__(self):
        return f"{self.__class__.__name__} (xyz={repr(self)}, color={self.color.rgb})"

# %%
import timeit

code_str = "ScanPoint(30.0, 30.0, 30.0, (255, 0, 0))"
time1 = timeit.timeit(code_str, setup="from __main__ import ScanPoint", number=1_000_000)
print(time1)

# %%
sp = ScanPoint(10, 20, 30, [255, 0, 0])
print(sp)

# %%
sp.x

# %%
[ScanPoint(10, 20, 30, [255, 0, 0]), ScanPoint(100, 200, 300, [255, 255, 255])]

# %%
ScanPoint.__mro__

# %%
# print(sp.__dict__)
print(sp.__slots__)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Скан

# %%
class Scan:

    def __init__(self):
        self._points = []

    def add_point(self, scan_point:ScanPoint):
        if isinstance(scan_point, ScanPoint):
            self._points.append(scan_point)

    def __repr__(self):
        return f"{self.__class__.__name__} (len={len(self)})"

    def __len__(self):
        return len(self._points)

    def __iter__(self):
        return iter(self._points)

# %%
sp1 = ScanPoint(10, 20, 30, (255, 0, 0))
sp2 = ScanPoint(20, 20, 30, (255, 0, 0))
sp3 = ScanPoint(30, 20, 30, (255, 0, 0))

scan = Scan()
[scan.add_point(point) for point in [sp1, sp2, sp3]]
print(scan)

print("=" * 50)

for point in scan:
    print(point)

# %% [markdown]
# ---
